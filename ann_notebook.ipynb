# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score
from scikeras.wrappers import KerasRegressor
from sklearn.model_selection import GridSearchCV
from joblib import dump, load
import shap

# %%
df = pd.read_csv("macro-economic-db-quarterly.csv", delimiter=";", index_col=0)
df = df.transpose()

df.reset_index(inplace=True)
df.rename(columns={"index":"stvrtrok"}, inplace=True)
for column in df.columns[1:]:
    df[column] = df[column].str.replace(",", "").astype(float)

columns_to_modify = df.columns.difference(["urok"])
df[columns_to_modify] = df[columns_to_modify].replace(0, np.nan)

df["bilancia"] = df.vyvoz - df.dovoz

df["NaN_Percentage"] = df.isna().sum(axis=1) / df.shape[1] * 100
df_cut =  df[df["NaN_Percentage"] <= 30].drop(columns=["NaN_Percentage"])
df_cut.reset_index(drop=True, inplace=True)

df_clean = df_cut.bfill()
df_clean = df_clean.ffill()

# %%
# Inicializácia štandardizérov
scaler_X = StandardScaler()
scaler_y_hdp = StandardScaler()
scaler_y_nezamestnanost = StandardScaler()
scaler_y_cpi = StandardScaler()

# HDP
X_hdp = df_clean[df_clean.columns.difference(["hdp", "stvrtrok"])]
y_hdp = df_clean.hdp.values.reshape(-1, 1)  # Reshape pre škálovanie

X_train_hdp, X_test_hdp, y_train_hdp, y_test_hdp = train_test_split(X_hdp, y_hdp, test_size=0.2, random_state=42)

# Štandardizácia
X_train_hdp = scaler_X.fit_transform(X_train_hdp)
X_test_hdp = scaler_X.transform(X_test_hdp)
y_train_hdp = scaler_y_hdp.fit_transform(y_train_hdp)
y_test_hdp = scaler_y_hdp.transform(y_test_hdp)

# Nezamestnanosť
X_nezamestnanost = df_clean[df_clean.columns.difference(["nezamestnanost", "stvrtrok"])]
y_nezamestnanost = df_clean.nezamestnanost.values.reshape(-1, 1)  # Reshape pre škálovanie

X_train_nezamestnanost, X_test_nezamestnanost, y_train_nezamestnanost, y_test_nezamestnanost = train_test_split(
    X_nezamestnanost, y_nezamestnanost, test_size=0.2, random_state=42
)

# Štandardizácia
X_train_nezamestnanost = scaler_X.fit_transform(X_train_nezamestnanost)
X_test_nezamestnanost = scaler_X.transform(X_test_nezamestnanost)
y_train_nezamestnanost = scaler_y_nezamestnanost.fit_transform(y_train_nezamestnanost)
y_test_nezamestnanost = scaler_y_nezamestnanost.transform(y_test_nezamestnanost)

# Inflácia (CPI)
X_cpi = df_clean[df_clean.columns.difference(["cpi", "stvrtrok"])]
y_cpi = df_clean.cpi.values.reshape(-1, 1)  # Reshape pre škálovanie

X_train_cpi, X_test_cpi, y_train_cpi, y_test_cpi = train_test_split(X_cpi, y_cpi, test_size=0.2, random_state=42)

# Štandardizácia
X_train_cpi = scaler_X.fit_transform(X_train_cpi)
X_test_cpi = scaler_X.transform(X_test_cpi)
y_train_cpi = scaler_y_cpi.fit_transform(y_train_cpi)
y_test_cpi = scaler_y_cpi.transform(y_test_cpi)

# %%
# Funkcia na vytvorenie ANN modelu (s hyperparametrami pre GridSearch)
def create_model(neurons_1=128, neurons_2=64, neurons_3=32, dropout_rate=0.2, optimizer='adam'):
    model = Sequential([
        Dense(neurons_1, activation='relu', input_shape=(X_train_hdp.shape[1],)),  # Vstupná vrstva
        Dropout(dropout_rate),  # Regularizácia
        Dense(neurons_2, activation='relu'),  # Skrytá vrstva
        Dense(neurons_3, activation='relu'),  # Skrytá vrstva
        Dense(1, activation='linear')  # Výstupná vrstva (regresia)
    ])
    model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mae'])
    return model

# Zabalenie modelu pre GridSearch
model = KerasRegressor(model=create_model, verbose=0)

# Definícia hyperparametrov pre GridSearch
param_grid = {
    'model__neurons_1': [64, 128, 256],  # Počet neurónov v prvej vrstve
    'model__neurons_2': [32, 64],  # Počet neurónov v druhej vrstve
    'model__neurons_3': [16, 32],  # Počet neurónov v tretej vrstve
    'model__dropout_rate': [0.2, 0.3, 0.4],  # Dropout rate
    'model__optimizer': ['adam', 'rmsprop'],  # Optimalizátor
    'batch_size': [16, 32],  # Veľkosť batchu
    'epochs': [50, 100]  # Počet epoch
}

# Spustenie GridSearchCV na tréningných dátach
grid = GridSearchCV(estimator=model, param_grid=param_grid, cv=3, scoring='neg_mean_absolute_error', n_jobs=-1, verbose=0)
grid_result = grid.fit(X_train_hdp, y_train_hdp)

# Výpis najlepších parametrov
print("Najlepšie parametre:", grid_result.best_params_)


# Trénovanie najlepšieho modelu na celých tréningných dátach
best_params = grid_result.best_params_
best_model_hdp = create_model(neurons_1=best_params['model__neurons_1'], 
                          neurons_2=best_params['model__neurons_2'],
                          neurons_3=best_params['model__neurons_3'],
                          dropout_rate=best_params['model__dropout_rate'],
                          optimizer=best_params['model__optimizer'])

history = best_model_hdp.fit(X_train_hdp, y_train_hdp, 
                         epochs=best_params['epochs'], batch_size=best_params['batch_size'], 
                         validation_data=(X_test_hdp, y_test_hdp), verbose=1)

# Predikcia na testovacej množine
y_pred = best_model_hdp.predict(X_test_hdp)

# Reskalovanie predikovaných hodnôt späť do pôvodného rozsahu
y_pred_rescaled = scaler_y_hdp.inverse_transform(y_pred)
y_test_rescaled = scaler_y_hdp.inverse_transform(y_test_hdp)

# Výpočet metrík (MSE, RMSE, MAE, MAPE, R2)
mse = mean_squared_error(y_test_rescaled, y_pred_rescaled)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test_rescaled, y_pred_rescaled)
mape = mean_absolute_percentage_error(y_test_rescaled, y_pred_rescaled)
r2 = r2_score(y_test_rescaled, y_pred_rescaled)

# Výpis výsledkov
print(f"MSE: {mse}")
print(f"RMSE: {rmse}")
print(f"MAE: {mae}")
print(f"MAPE: {mape}")
print(f"R2: {r2}")

# %%
# ANN Model pre Nezamestnanosť

# Funkcia na vytvorenie ANN modelu (s hyperparametrami pre GridSearch)
def create_model(neurons_1=128, neurons_2=64, neurons_3=32, dropout_rate=0.2, optimizer='adam'):
    model = Sequential([
        Dense(neurons_1, activation='relu', input_shape=(X_train_nezamestnanost.shape[1],)),  # Vstupná vrstva
        Dropout(dropout_rate),  # Regularizácia
        Dense(neurons_2, activation='relu'),  # Skrytá vrstva
        Dense(neurons_3, activation='relu'),  # Skrytá vrstva
        Dense(1, activation='linear')  # Výstupná vrstva (regresia)
    ])
    model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mae'])
    return model

# Zabalenie modelu pre GridSearch
model = KerasRegressor(model=create_model, verbose=0)

# Definícia hyperparametrov pre GridSearch
param_grid = {
    'model__neurons_1': [64, 128, 256],  # Počet neurónov v prvej vrstve
    'model__neurons_2': [32, 64],  # Počet neurónov v druhej vrstve
    'model__neurons_3': [16, 32],  # Počet neurónov v tretej vrstve
    'model__dropout_rate': [0.2, 0.3, 0.4],  # Dropout rate
    'model__optimizer': ['adam', 'rmsprop'],  # Optimalizátor
    'batch_size': [16, 32],  # Veľkosť batchu
    'epochs': [50, 100]  # Počet epoch
}


# Spustenie GridSearchCV na tréningných dátach
grid = GridSearchCV(estimator=model, param_grid=param_grid, cv=3, scoring='neg_mean_absolute_error', n_jobs=-1, verbose=0)
grid_result = grid.fit(X_train_nezamestnanost, y_train_nezamestnanost)

# Výpis najlepších parametrov
print("Najlepšie parametre:", grid_result.best_params_)


# Trénovanie najlepšieho modelu na celých tréningných dátach
best_params = grid_result.best_params_
best_model_nezamestnanost = create_model(neurons_1=best_params['model__neurons_1'], 
                          neurons_2=best_params['model__neurons_2'],
                          neurons_3=best_params['model__neurons_3'],
                          dropout_rate=best_params['model__dropout_rate'],
                          optimizer=best_params['model__optimizer'])

history = best_model_nezamestnanost.fit(X_train_nezamestnanost, y_train_nezamestnanost, 
                         epochs=best_params['epochs'], batch_size=best_params['batch_size'], 
                         validation_data=(X_test_nezamestnanost, y_test_nezamestnanost), verbose=1)

# Predikcia na testovacej množine
y_pred = best_model_nezamestnanost.predict(X_test_nezamestnanost)

# Reskalovanie predikovaných hodnôt späť do pôvodného rozsahu
y_pred_rescaled = scaler_y_nezamestnanost.inverse_transform(y_pred)
y_test_rescaled = scaler_y_nezamestnanost.inverse_transform(y_test_nezamestnanost)

# Výpočet metrík (MSE, RMSE, MAE, MAPE, R2)
mse = mean_squared_error(y_test_rescaled, y_pred_rescaled)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test_rescaled, y_pred_rescaled)
mape = mean_absolute_percentage_error(y_test_rescaled, y_pred_rescaled)
r2 = r2_score(y_test_rescaled, y_pred_rescaled)

# Výpis výsledkov
print(f"MSE: {mse}")
print(f"RMSE: {rmse}")
print(f"MAE: {mae}")
print(f"MAPE: {mape}")
print(f"R2: {r2}")
# Out:
# c:\Users\ASFoj\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Najlepšie parametre: {'batch_size': 16, 'epochs': 100, 'model__dropout_rate': 0.2, 'model__neurons_1': 256, 'model__neurons_2': 32, 'model__neurons_3': 32, 'model__optimizer': 'adam'}
# Epoch 1/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.8555 - mae: 0.7935 - val_loss: 0.2606 - val_mae: 0.4367
# Epoch 2/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3283 - mae: 0.5038 - val_loss: 0.2846 - val_mae: 0.4593
# Epoch 3/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2566 - mae: 0.4182 - val_loss: 0.2290 - val_mae: 0.3505
# Epoch 4/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2095 - mae: 0.3569 - val_loss: 0.1424 - val_mae: 0.3072
# Epoch 5/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1871 - mae: 0.3708 - val_loss: 0.0934 - val_mae: 0.2504
# Epoch 6/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1464 - mae: 0.3086 - val_loss: 0.0743 - val_mae: 0.2180
# Epoch 7/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1137 - mae: 0.2786 - val_loss: 0.0457 - val_mae: 0.1691
# Epoch 8/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0752 - mae: 0.2202 - val_loss: 0.0342 - val_mae: 0.1502
# Epoch 9/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0934 - mae: 0.2430 - val_loss: 0.0308 - val_mae: 0.1414
# Epoch 10/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0853 - mae: 0.2445 - val_loss: 0.0312 - val_mae: 0.1377
# Epoch 11/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0627 - mae: 0.1975 - val_loss: 0.0323 - val_mae: 0.1455
# Epoch 12/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0696 - mae: 0.2174 - val_loss: 0.0329 - val_mae: 0.1458
# Epoch 13/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0582 - mae: 0.1895 - val_loss: 0.0368 - val_mae: 0.1379
# Epoch 14/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0619 - mae: 0.2046 - val_loss: 0.0244 - val_mae: 0.1159
# Epoch 15/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0470 - mae: 0.1733 - val_loss: 0.0309 - val_mae: 0.1250
# Epoch 16/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0608 - mae: 0.2062 - val_loss: 0.0297 - val_mae: 0.1200
# Epoch 17/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0490 - mae: 0.1770 - val_loss: 0.0279 - val_mae: 0.1163
# Epoch 18/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0501 - mae: 0.1777 - val_loss: 0.0290 - val_mae: 0.1182
# Epoch 19/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0365 - mae: 0.1584 - val_loss: 0.0203 - val_mae: 0.1040
# Epoch 20/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0377 - mae: 0.1588 - val_loss: 0.0239 - val_mae: 0.1108
# Epoch 21/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0572 - mae: 0.1710 - val_loss: 0.0404 - val_mae: 0.1524
# Epoch 22/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0422 - mae: 0.1710 - val_loss: 0.0238 - val_mae: 0.1094
# Epoch 23/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0279 - mae: 0.1297 - val_loss: 0.0202 - val_mae: 0.1024
# Epoch 24/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0369 - mae: 0.1555 - val_loss: 0.0262 - val_mae: 0.1151
# Epoch 25/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0286 - mae: 0.1324 - val_loss: 0.0220 - val_mae: 0.1120
# Epoch 26/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0211 - mae: 0.1182 - val_loss: 0.0259 - val_mae: 0.1211
# Epoch 27/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0366 - mae: 0.1553 - val_loss: 0.0231 - val_mae: 0.1163
# Epoch 28/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0339 - mae: 0.1467 - val_loss: 0.0262 - val_mae: 0.1179
# Epoch 29/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0301 - mae: 0.1339 - val_loss: 0.0273 - val_mae: 0.1155
# Epoch 30/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0323 - mae: 0.1501 - val_loss: 0.0175 - val_mae: 0.0875
# Epoch 31/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0247 - mae: 0.1266 - val_loss: 0.0290 - val_mae: 0.1281
# Epoch 32/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0219 - mae: 0.1133 - val_loss: 0.0231 - val_mae: 0.1121
# Epoch 33/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0304 - mae: 0.1380 - val_loss: 0.0224 - val_mae: 0.1094
# Epoch 34/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0243 - mae: 0.1257 - val_loss: 0.0173 - val_mae: 0.0925
# Epoch 35/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0207 - mae: 0.1092 - val_loss: 0.0160 - val_mae: 0.0871
# Epoch 36/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0259 - mae: 0.1287 - val_loss: 0.0179 - val_mae: 0.0923
# Epoch 37/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0198 - mae: 0.1058 - val_loss: 0.0211 - val_mae: 0.1006
# Epoch 38/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0228 - mae: 0.1119 - val_loss: 0.0207 - val_mae: 0.1134
# Epoch 39/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0193 - mae: 0.1064 - val_loss: 0.0199 - val_mae: 0.1073
# Epoch 40/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0217 - mae: 0.1159 - val_loss: 0.0264 - val_mae: 0.1269
# Epoch 41/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0316 - mae: 0.1313 - val_loss: 0.0332 - val_mae: 0.1442
# Epoch 42/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0196 - mae: 0.1087 - val_loss: 0.0217 - val_mae: 0.1067
# Epoch 43/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0177 - mae: 0.1050 - val_loss: 0.0164 - val_mae: 0.0917
# Epoch 44/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0183 - mae: 0.1076 - val_loss: 0.0178 - val_mae: 0.1064
# Epoch 45/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0164 - mae: 0.0994 - val_loss: 0.0282 - val_mae: 0.1341
# Epoch 46/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0318 - mae: 0.1274 - val_loss: 0.0216 - val_mae: 0.1169
# Epoch 47/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0207 - mae: 0.1122 - val_loss: 0.0171 - val_mae: 0.1040
# Epoch 48/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0188 - mae: 0.1050 - val_loss: 0.0163 - val_mae: 0.0886
# Epoch 49/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0214 - mae: 0.1114 - val_loss: 0.0304 - val_mae: 0.1273
# Epoch 50/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0187 - mae: 0.1026 - val_loss: 0.0226 - val_mae: 0.1154
# Epoch 51/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0124 - mae: 0.0903 - val_loss: 0.0195 - val_mae: 0.1081
# Epoch 52/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0187 - mae: 0.1006 - val_loss: 0.0273 - val_mae: 0.1275
# Epoch 53/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0171 - mae: 0.1026 - val_loss: 0.0269 - val_mae: 0.1153
# Epoch 54/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0226 - mae: 0.1168 - val_loss: 0.0167 - val_mae: 0.0930
# Epoch 55/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0185 - mae: 0.1032 - val_loss: 0.0258 - val_mae: 0.1247
# Epoch 56/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0189 - mae: 0.1109 - val_loss: 0.0195 - val_mae: 0.1049
# Epoch 57/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0190 - mae: 0.1066 - val_loss: 0.0208 - val_mae: 0.1072
# Epoch 58/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0171 - mae: 0.1086 - val_loss: 0.0204 - val_mae: 0.1123
# Epoch 59/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0212 - mae: 0.1189 - val_loss: 0.0204 - val_mae: 0.1071
# Epoch 60/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0159 - mae: 0.0957 - val_loss: 0.0213 - val_mae: 0.1132
# Epoch 61/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0136 - mae: 0.0952 - val_loss: 0.0236 - val_mae: 0.1159
# Epoch 62/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0170 - mae: 0.1043 - val_loss: 0.0153 - val_mae: 0.0907
# Epoch 63/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0161 - mae: 0.0974 - val_loss: 0.0194 - val_mae: 0.1038
# Epoch 64/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0201 - mae: 0.1082 - val_loss: 0.0217 - val_mae: 0.1105
# Epoch 65/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0224 - mae: 0.1181 - val_loss: 0.0127 - val_mae: 0.0848
# Epoch 66/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0187 - mae: 0.1173 - val_loss: 0.0216 - val_mae: 0.1129
# Epoch 67/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0122 - mae: 0.0894 - val_loss: 0.0231 - val_mae: 0.1174
# Epoch 68/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0142 - mae: 0.0988 - val_loss: 0.0146 - val_mae: 0.0917
# Epoch 69/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0143 - mae: 0.0942 - val_loss: 0.0227 - val_mae: 0.1166
# Epoch 70/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0132 - mae: 0.0868 - val_loss: 0.0226 - val_mae: 0.1148
# Epoch 71/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0116 - mae: 0.0804 - val_loss: 0.0220 - val_mae: 0.1174
# Epoch 72/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0148 - mae: 0.1018 - val_loss: 0.0197 - val_mae: 0.1129
# Epoch 73/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0138 - mae: 0.0952 - val_loss: 0.0182 - val_mae: 0.1074
# Epoch 74/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0143 - mae: 0.0898 - val_loss: 0.0208 - val_mae: 0.1135
# Epoch 75/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0125 - mae: 0.0857 - val_loss: 0.0198 - val_mae: 0.1070
# Epoch 76/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0100 - mae: 0.0797 - val_loss: 0.0138 - val_mae: 0.0892
# Epoch 77/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0148 - mae: 0.0913 - val_loss: 0.0167 - val_mae: 0.1009
# Epoch 78/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0137 - mae: 0.0926 - val_loss: 0.0209 - val_mae: 0.1044
# Epoch 79/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0157 - mae: 0.0978 - val_loss: 0.0168 - val_mae: 0.0975
# Epoch 80/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0100 - mae: 0.0757 - val_loss: 0.0189 - val_mae: 0.1051
# Epoch 81/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0157 - mae: 0.0994 - val_loss: 0.0163 - val_mae: 0.1003
# Epoch 82/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0097 - mae: 0.0772 - val_loss: 0.0182 - val_mae: 0.1021
# Epoch 83/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0113 - mae: 0.0774 - val_loss: 0.0172 - val_mae: 0.1008
# Epoch 84/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0119 - mae: 0.0826 - val_loss: 0.0117 - val_mae: 0.0849
# Epoch 85/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0169 - mae: 0.1017 - val_loss: 0.0181 - val_mae: 0.1012
# Epoch 86/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0133 - mae: 0.0888 - val_loss: 0.0225 - val_mae: 0.1166
# Epoch 87/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0111 - mae: 0.0831 - val_loss: 0.0198 - val_mae: 0.1081
# Epoch 88/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0100 - mae: 0.0808 - val_loss: 0.0249 - val_mae: 0.1244
# Epoch 89/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0169 - mae: 0.1037 - val_loss: 0.0214 - val_mae: 0.1187
# Epoch 90/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0127 - mae: 0.0882 - val_loss: 0.0134 - val_mae: 0.0916
# Epoch 91/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0091 - mae: 0.0774 - val_loss: 0.0205 - val_mae: 0.1071
# Epoch 92/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0116 - mae: 0.0849 - val_loss: 0.0227 - val_mae: 0.1037
# Epoch 93/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0111 - mae: 0.0808 - val_loss: 0.0159 - val_mae: 0.0885
# Epoch 94/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0101 - mae: 0.0804 - val_loss: 0.0152 - val_mae: 0.0923
# Epoch 95/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0113 - mae: 0.0780 - val_loss: 0.0193 - val_mae: 0.1091
# Epoch 96/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0100 - mae: 0.0793 - val_loss: 0.0153 - val_mae: 0.0934
# Epoch 97/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0106 - mae: 0.0834 - val_loss: 0.0146 - val_mae: 0.0881
# Epoch 98/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0079 - mae: 0.0716 - val_loss: 0.0263 - val_mae: 0.1245
# Epoch 99/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0111 - mae: 0.0882 - val_loss: 0.0209 - val_mae: 0.1135
# Epoch 100/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0117 - mae: 0.0865 - val_loss: 0.0176 - val_mae: 0.1039
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# MSE: 0.3391612851250473
# RMSE: 0.5823755533374039
# MAE: 0.4561674606654955
# MAPE: 0.04558646876513552
# R2: 0.9776723844307753

# %%
# Funkcia na vytvorenie ANN modelu (s hyperparametrami pre GridSearch)
def create_model(neurons_1=128, neurons_2=64, neurons_3=32, dropout_rate=0.2, optimizer='adam'):
    model = Sequential([
        Dense(neurons_1, activation='relu', input_shape=(X_train_cpi.shape[1],)),  # Vstupná vrstva
        Dropout(dropout_rate),  # Regularizácia
        Dense(neurons_2, activation='relu'),  # Skrytá vrstva
        Dense(neurons_3, activation='relu'),  # Skrytá vrstva
        Dense(1, activation='linear')  # Výstupná vrstva (regresia)
    ])
    model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mae'])
    return model

# Zabalenie modelu pre GridSearch
model = KerasRegressor(model=create_model, verbose=0)

# Definícia hyperparametrov pre GridSearch
param_grid = {
    'model__neurons_1': [64, 128, 256],  # Počet neurónov v prvej vrstve
    'model__neurons_2': [32, 64],  # Počet neurónov v druhej vrstve
    'model__neurons_3': [16, 32],  # Počet neurónov v tretej vrstve
    'model__dropout_rate': [0.2, 0.3, 0.4],  # Dropout rate
    'model__optimizer': ['adam', 'rmsprop'],  # Optimalizátor
    'batch_size': [16, 32],  # Veľkosť batchu
    'epochs': [50, 100]  # Počet epoch
}


# Spustenie GridSearchCV na tréningných dátach
grid = GridSearchCV(estimator=model, param_grid=param_grid, cv=3, scoring='neg_mean_absolute_error', n_jobs=-1, verbose=0)
grid_result = grid.fit(X_train_cpi, y_train_cpi)

# Výpis najlepších parametrov
print("Najlepšie parametre:", grid_result.best_params_)


# Trénovanie najlepšieho modelu na celých tréningných dátach
best_params = grid_result.best_params_
best_model_cpi = create_model(neurons_1=best_params['model__neurons_1'], 
                          neurons_2=best_params['model__neurons_2'],
                          neurons_3=best_params['model__neurons_3'],
                          dropout_rate=best_params['model__dropout_rate'],
                          optimizer=best_params['model__optimizer'])

history = best_model_cpi.fit(X_train_cpi, y_train_cpi, 
                         epochs=best_params['epochs'], batch_size=best_params['batch_size'], 
                         validation_data=(X_test_cpi, y_test_cpi), verbose=1)

# Predikcia na testovacej množine
y_pred = best_model_cpi.predict(X_test_cpi)

# Reskalovanie predikovaných hodnôt späť do pôvodného rozsahu
y_pred_rescaled = scaler_y_cpi.inverse_transform(y_pred)
y_test_rescaled = scaler_y_cpi.inverse_transform(y_test_cpi)

# Výpočet metrík (MSE, RMSE, MAE, MAPE, R2)
mse = mean_squared_error(y_test_rescaled, y_pred_rescaled)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test_rescaled, y_pred_rescaled)
mape = mean_absolute_percentage_error(y_test_rescaled, y_pred_rescaled)
r2 = r2_score(y_test_rescaled, y_pred_rescaled)

# Výpis výsledkov
print(f"MSE: {mse}")
print(f"RMSE: {rmse}")
print(f"MAE: {mae}")
print(f"MAPE: {mape}")
print(f"R2: {r2}")
# Out:
# c:\Users\ASFoj\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\externals\loky\process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# c:\Users\ASFoj\AppData\Local\Programs\Python\Python312\Lib\site-packages\numpy\ma\core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# c:\Users\ASFoj\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Najlepšie parametre: {'batch_size': 16, 'epochs': 100, 'model__dropout_rate': 0.2, 'model__neurons_1': 256, 'model__neurons_2': 32, 'model__neurons_3': 32, 'model__optimizer': 'adam'}
# Najlepší MAE skóre: 0.054214546006869015
# Epoch 1/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.6594 - mae: 0.5988 - val_loss: 0.3911 - val_mae: 0.4315
# Epoch 2/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2216 - mae: 0.3318 - val_loss: 0.1655 - val_mae: 0.2466
# Epoch 3/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0990 - mae: 0.2296 - val_loss: 0.0744 - val_mae: 0.2017
# Epoch 4/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0672 - mae: 0.2133 - val_loss: 0.0453 - val_mae: 0.1649
# Epoch 5/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0374 - mae: 0.1545 - val_loss: 0.0271 - val_mae: 0.1073
# Epoch 6/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0228 - mae: 0.1149 - val_loss: 0.0342 - val_mae: 0.1482
# Epoch 7/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0296 - mae: 0.1253 - val_loss: 0.0146 - val_mae: 0.0897
# Epoch 8/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0169 - mae: 0.0964 - val_loss: 0.0132 - val_mae: 0.0947
# Epoch 9/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0270 - mae: 0.1167 - val_loss: 0.0087 - val_mae: 0.0769
# Epoch 10/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0136 - mae: 0.0858 - val_loss: 0.0075 - val_mae: 0.0745
# Epoch 11/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0141 - mae: 0.0933 - val_loss: 0.0062 - val_mae: 0.0679
# Epoch 12/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0150 - mae: 0.0938 - val_loss: 0.0049 - val_mae: 0.0560
# Epoch 13/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0210 - mae: 0.1079 - val_loss: 0.0085 - val_mae: 0.0765
# Epoch 14/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0120 - mae: 0.0819 - val_loss: 0.0035 - val_mae: 0.0496
# Epoch 15/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0186 - mae: 0.0965 - val_loss: 0.0034 - val_mae: 0.0478
# Epoch 16/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0133 - mae: 0.0838 - val_loss: 0.0027 - val_mae: 0.0414
# Epoch 17/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0142 - mae: 0.0869 - val_loss: 0.0039 - val_mae: 0.0493
# Epoch 18/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0143 - mae: 0.0892 - val_loss: 0.0021 - val_mae: 0.0375
# Epoch 19/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0112 - mae: 0.0817 - val_loss: 0.0021 - val_mae: 0.0380
# Epoch 20/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0103 - mae: 0.0695 - val_loss: 0.0064 - val_mae: 0.0632
# Epoch 21/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0131 - mae: 0.0784 - val_loss: 0.0029 - val_mae: 0.0421
# Epoch 22/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0104 - mae: 0.0762 - val_loss: 0.0028 - val_mae: 0.0431
# Epoch 23/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0110 - mae: 0.0787 - val_loss: 0.0026 - val_mae: 0.0407
# Epoch 24/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0122 - mae: 0.0778 - val_loss: 0.0026 - val_mae: 0.0410
# Epoch 25/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0207 - mae: 0.0928 - val_loss: 0.0043 - val_mae: 0.0525
# Epoch 26/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0134 - mae: 0.0866 - val_loss: 0.0044 - val_mae: 0.0535
# Epoch 27/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0088 - mae: 0.0707 - val_loss: 0.0038 - val_mae: 0.0510
# Epoch 28/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0154 - mae: 0.0841 - val_loss: 0.0068 - val_mae: 0.0604
# Epoch 29/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0097 - mae: 0.0710 - val_loss: 0.0070 - val_mae: 0.0640
# Epoch 30/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0106 - mae: 0.0789 - val_loss: 0.0029 - val_mae: 0.0434
# Epoch 31/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0084 - mae: 0.0731 - val_loss: 0.0026 - val_mae: 0.0425
# Epoch 32/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0091 - mae: 0.0718 - val_loss: 0.0024 - val_mae: 0.0392
# Epoch 33/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0114 - mae: 0.0790 - val_loss: 0.0031 - val_mae: 0.0453
# Epoch 34/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0097 - mae: 0.0682 - val_loss: 0.0030 - val_mae: 0.0449
# Epoch 35/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0085 - mae: 0.0703 - val_loss: 0.0021 - val_mae: 0.0378
# Epoch 36/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0069 - mae: 0.0600 - val_loss: 0.0022 - val_mae: 0.0389
# Epoch 37/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0074 - mae: 0.0671 - val_loss: 0.0024 - val_mae: 0.0406
# Epoch 38/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0058 - mae: 0.0584 - val_loss: 0.0074 - val_mae: 0.0693
# Epoch 39/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0161 - mae: 0.0879 - val_loss: 0.0056 - val_mae: 0.0595
# Epoch 40/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0148 - mae: 0.0852 - val_loss: 0.0025 - val_mae: 0.0409
# Epoch 41/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0095 - mae: 0.0758 - val_loss: 0.0023 - val_mae: 0.0386
# Epoch 42/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0087 - mae: 0.0730 - val_loss: 0.0081 - val_mae: 0.0760
# Epoch 43/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0122 - mae: 0.0845 - val_loss: 0.0015 - val_mae: 0.0320
# Epoch 44/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0087 - mae: 0.0684 - val_loss: 0.0024 - val_mae: 0.0411
# Epoch 45/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0073 - mae: 0.0642 - val_loss: 0.0029 - val_mae: 0.0434
# Epoch 46/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0079 - mae: 0.0623 - val_loss: 0.0041 - val_mae: 0.0504
# Epoch 47/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0069 - mae: 0.0629 - val_loss: 0.0031 - val_mae: 0.0396
# Epoch 48/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0086 - mae: 0.0611 - val_loss: 0.0050 - val_mae: 0.0554
# Epoch 49/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0084 - mae: 0.0643 - val_loss: 0.0012 - val_mae: 0.0306
# Epoch 50/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0069 - mae: 0.0623 - val_loss: 0.0017 - val_mae: 0.0358
# Epoch 51/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0083 - mae: 0.0621 - val_loss: 0.0017 - val_mae: 0.0331
# Epoch 52/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0044 - mae: 0.0486 - val_loss: 0.0021 - val_mae: 0.0378
# Epoch 53/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0049 - mae: 0.0512 - val_loss: 0.0021 - val_mae: 0.0371
# Epoch 54/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0090 - mae: 0.0652 - val_loss: 0.0025 - val_mae: 0.0422
# Epoch 55/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0114 - mae: 0.0731 - val_loss: 0.0017 - val_mae: 0.0337
# Epoch 56/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0071 - mae: 0.0658 - val_loss: 0.0032 - val_mae: 0.0448
# Epoch 57/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0065 - mae: 0.0561 - val_loss: 0.0027 - val_mae: 0.0413
# Epoch 58/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0080 - mae: 0.0635 - val_loss: 0.0014 - val_mae: 0.0312
# Epoch 59/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0051 - mae: 0.0505 - val_loss: 0.0067 - val_mae: 0.0654
# Epoch 60/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0066 - mae: 0.0574 - val_loss: 0.0030 - val_mae: 0.0414
# Epoch 61/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0074 - mae: 0.0663 - val_loss: 0.0023 - val_mae: 0.0395
# Epoch 62/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0075 - mae: 0.0610 - val_loss: 0.0056 - val_mae: 0.0574
# Epoch 63/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0060 - mae: 0.0576 - val_loss: 0.0050 - val_mae: 0.0553
# Epoch 64/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0081 - mae: 0.0639 - val_loss: 0.0080 - val_mae: 0.0681
# Epoch 65/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0092 - mae: 0.0709 - val_loss: 0.0043 - val_mae: 0.0510
# Epoch 66/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0117 - mae: 0.0823 - val_loss: 0.0016 - val_mae: 0.0348
# Epoch 67/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0068 - mae: 0.0596 - val_loss: 0.0066 - val_mae: 0.0588
# Epoch 68/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0113 - mae: 0.0764 - val_loss: 0.0014 - val_mae: 0.0319
# Epoch 69/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0076 - mae: 0.0628 - val_loss: 0.0039 - val_mae: 0.0487
# Epoch 70/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0065 - mae: 0.0565 - val_loss: 0.0043 - val_mae: 0.0522
# Epoch 71/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0081 - mae: 0.0652 - val_loss: 0.0023 - val_mae: 0.0375
# Epoch 72/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0051 - mae: 0.0493 - val_loss: 0.0030 - val_mae: 0.0427
# Epoch 73/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0076 - mae: 0.0586 - val_loss: 0.0055 - val_mae: 0.0562
# Epoch 74/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0075 - mae: 0.0625 - val_loss: 0.0023 - val_mae: 0.0399
# Epoch 75/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0081 - mae: 0.0601 - val_loss: 0.0089 - val_mae: 0.0643
# Epoch 76/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0109 - mae: 0.0679 - val_loss: 0.0102 - val_mae: 0.0728
# Epoch 77/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0076 - mae: 0.0653 - val_loss: 0.0030 - val_mae: 0.0464
# Epoch 78/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0086 - mae: 0.0682 - val_loss: 0.0033 - val_mae: 0.0426
# Epoch 79/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0062 - mae: 0.0568 - val_loss: 0.0125 - val_mae: 0.0816
# Epoch 80/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0100 - mae: 0.0665 - val_loss: 0.0025 - val_mae: 0.0423
# Epoch 81/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0077 - mae: 0.0609 - val_loss: 0.0029 - val_mae: 0.0427
# Epoch 82/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0039 - mae: 0.0478 - val_loss: 0.0033 - val_mae: 0.0434
# Epoch 83/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0055 - mae: 0.0528 - val_loss: 0.0038 - val_mae: 0.0417
# Epoch 84/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0034 - mae: 0.0440 - val_loss: 0.0048 - val_mae: 0.0497
# Epoch 85/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0050 - mae: 0.0495 - val_loss: 0.0033 - val_mae: 0.0462
# Epoch 86/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0048 - mae: 0.0531 - val_loss: 0.0030 - val_mae: 0.0415
# Epoch 87/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0037 - mae: 0.0422 - val_loss: 0.0032 - val_mae: 0.0428
# Epoch 88/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0085 - mae: 0.0671 - val_loss: 0.0036 - val_mae: 0.0489
# Epoch 89/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0081 - mae: 0.0630 - val_loss: 0.0053 - val_mae: 0.0532
# Epoch 90/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0058 - mae: 0.0537 - val_loss: 0.0050 - val_mae: 0.0481
# Epoch 91/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0068 - mae: 0.0588 - val_loss: 0.0028 - val_mae: 0.0405
# Epoch 92/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0060 - mae: 0.0576 - val_loss: 0.0072 - val_mae: 0.0676
# Epoch 93/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0084 - mae: 0.0617 - val_loss: 0.0032 - val_mae: 0.0462
# Epoch 94/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0061 - mae: 0.0588 - val_loss: 0.0019 - val_mae: 0.0367
# Epoch 95/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0047 - mae: 0.0504 - val_loss: 0.0019 - val_mae: 0.0354
# Epoch 96/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0053 - mae: 0.0531 - val_loss: 0.0088 - val_mae: 0.0648
# Epoch 97/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0091 - mae: 0.0680 - val_loss: 0.0049 - val_mae: 0.0584
# Epoch 98/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0074 - mae: 0.0631 - val_loss: 0.0021 - val_mae: 0.0359
# Epoch 99/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0049 - mae: 0.0522 - val_loss: 0.0016 - val_mae: 0.0299
# Epoch 100/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0050 - mae: 0.0495 - val_loss: 0.0026 - val_mae: 0.0387
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# MSE: 3.8667192455231585
# RMSE: 1.9663975298812695
# MAE: 1.4991485128651483
# MAPE: 0.010089345291630804
# R2: 0.9982049515698347

# %%
# Uloženie modelov

#dump(best_model_hdp, 'best_model_hdp_ann.joblib')
#dump(best_model_nezamestnanost, 'best_model_nezamestnanost_ann.joblib')
#dump(best_model_cpi, 'best_model_cpi_ann.joblib')
# Out:
# ['best_model_cpi_ann.joblib']

# %%
# Načítanie modelov
ann_loaded_hdp = load('best_model_hdp_ann.joblib')
ann_loaded_nezamestnanost = load('best_model_nezamestnanost_ann.joblib')
ann_loaded_cpi = load('best_model_cpi_ann.joblib')

# %%
# Metriky

hdp_pred_loaded = scaler_y_hdp.inverse_transform(ann_loaded_hdp.predict(X_test_hdp))
nezamestnanost_pred_loaded = scaler_y_nezamestnanost.inverse_transform(ann_loaded_nezamestnanost.predict(X_test_nezamestnanost))
cpi_pred_loaded = scaler_y_cpi.inverse_transform(ann_loaded_cpi.predict(X_test_cpi))

y_test_hdp = scaler_y_hdp.inverse_transform(y_test_hdp)
y_test_nezamestnanost = scaler_y_nezamestnanost.inverse_transform(y_test_nezamestnanost)
y_test_cpi= scaler_y_cpi.inverse_transform(y_test_cpi)


mae_nezamestnanost_loaded = mean_absolute_error(y_test_nezamestnanost, nezamestnanost_pred_loaded)
mse_nezamestnanost_loaded = mean_squared_error(y_test_nezamestnanost, nezamestnanost_pred_loaded)
rmse_nezamestnanost_loaded = np.sqrt(mse_nezamestnanost_loaded)
mape_nezamestnanost_loaded = mean_absolute_percentage_error(y_test_nezamestnanost, nezamestnanost_pred_loaded)
r2_nezamestnanost_loaded = r2_score(y_test_nezamestnanost, nezamestnanost_pred_loaded)

mae_hdp_loaded = mean_absolute_error(y_test_hdp, hdp_pred_loaded)
mse_hdp_loaded = mean_squared_error(y_test_hdp, hdp_pred_loaded)
rmse_hdp_loaded = np.sqrt(mse_hdp_loaded)
mape_hdp_loaded = mean_absolute_percentage_error(y_test_hdp, hdp_pred_loaded)
r2_hdp_loaded = r2_score(y_test_hdp, hdp_pred_loaded)

mae_cpi_loaded = mean_absolute_error(y_test_cpi, cpi_pred_loaded)
mse_cpi_loaded = mean_squared_error(y_test_cpi, cpi_pred_loaded)
rmse_cpi_loaded = np.sqrt(mse_cpi_loaded)
mape_cpi_loaded = mean_absolute_percentage_error(y_test_cpi, cpi_pred_loaded)
r2_cpi_loaded = r2_score(y_test_cpi, cpi_pred_loaded)

metrics = {
    "Cieľová premenná": [
        "HDP",
        "Nezamestnanosť",
        "Inflácia"
    ],
    "MSE": [
        mse_hdp_loaded,
        mse_nezamestnanost_loaded,
        mse_cpi_loaded
    ],
    "MAE": [
        mae_hdp_loaded,
        mae_nezamestnanost_loaded,
        mae_cpi_loaded,
    ],
    "RMSE": [
        rmse_hdp_loaded,
        rmse_nezamestnanost_loaded,
        rmse_cpi_loaded
    ],
    "MAPE": [
        mape_hdp_loaded,
        mape_nezamestnanost_loaded,
        mape_cpi_loaded
    ],
    "R2": [
        r2_hdp_loaded,
        r2_nezamestnanost_loaded,
        r2_cpi_loaded
    ]
}

df_metrics = pd.DataFrame(metrics)
df_metrics
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
#   Cieľová premenná            MSE         MAE        RMSE      MAPE        R2
# 0              HDP  132749.699655  281.207897  364.348322  0.017568  0.994968
# 1   Nezamestnanosť       0.526307    0.540254    0.725470  0.046316  0.965352
# 2         Inflácia       3.866719    1.499149    1.966398  0.010089  0.998205

# %%
import shap
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import joblib

# Slovník so všetkými modelmi a príslušnými dátami
models = {
    "HDP": {"model": ann_loaded_hdp, "X_test": X_test_hdp, "feature_names": X_hdp.columns},
    "Nezamestnanosť": {"model": ann_loaded_nezamestnanost, "X_test": X_test_nezamestnanost, "feature_names": X_nezamestnanost.columns},
    "CPI": {"model": ann_loaded_cpi, "X_test": X_test_cpi, "feature_names": X_cpi.columns}
}


fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(10, 15))


for idx, (target, data) in enumerate(models.items()):
    model = data["model"]
    feature_names = data["feature_names"]
    X_test = data["X_test"]


    # Inicializácia modelu
    _ = model.predict(np.zeros((1, X_test.shape[1]), dtype=np.float32))  # Inicializácia vstupu

    # Inicializácia SHAP GradientExplainer
    explainer = shap.GradientExplainer(model, X_test[:50])  # Použijeme 50 vzoriek pre vysvetlenie

    # Výpočet SHAP hodnôt
    shap_values = explainer.shap_values(X_test[:200])  # Použijeme 200 vzoriek

    # Spracovanie výstupu SHAP na 1D pole
    if isinstance(shap_values, list):  # Ak model má viac výstupov, spriemerujeme cez všetky výstupy
        shap_values = np.mean(np.abs(shap_values), axis=(0, 1))
    else:
        shap_values = np.mean(np.abs(shap_values), axis=0)

    # Normalizácia tak, aby súčet výzanmností = 1 (ako v stromových modeloch)
    shap_values /= shap_values.sum()

    # Vytvorenie DataFrame pre vizualizáciu
    feature_importance_df = pd.DataFrame({
        "Premenná": feature_names,
        "Významnosť": shap_values.flatten()
    }).sort_values(by="Významnosť", ascending=False)

    # Vykreslenie grafu výzanmnosti premenných na príslušnej subplot osi
    ax = axes[idx]
    ax.barh(feature_importance_df["Premenná"], feature_importance_df["Významnosť"], color="blue")
    ax.set_xlabel("Významnosť")
    ax.set_ylabel("Premenná")
    ax.set_title(f"Významnosť premenných pre {target}")
    ax.invert_yaxis() 


plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
